# %%
from elasticsearch import Elasticsearch, helpers

es = Elasticsearch("https://astrolastic.francecentral.cloudapp.azure.com:9200", basic_auth=("elastic", "JrEsrnMgAPibhDTf6W*Z"), verify_certs=False)
# Out:
# c:\Users\omar_\AppData\Local\Programs\Python\Python313\Lib\site-packages\elasticsearch\_sync\client\__init__.py:313: SecurityWarning: Connecting to 'https://astrolastic.francecentral.cloudapp.azure.com:9200' using TLS with verify_certs=False is insecure
#   _transport = transport_class(

# %%
print(es.info())
# Out:
# {'name': 'a85f9ff510d2', 'cluster_name': 'docker-cluster', 'cluster_uuid': 't9qotGQ_R0ydLvpiUJEwcg', 'version': {'number': '9.2.2', 'build_flavor': 'default', 'build_type': 'docker', 'build_hash': 'ed771e6976fac1a085affabd45433234a4babeaf', 'build_date': '2025-11-27T08:06:51.614397514Z', 'build_snapshot': False, 'lucene_version': '10.3.2', 'minimum_wire_compatibility_version': '8.19.0', 'minimum_index_compatibility_version': '8.0.0'}, 'tagline': 'You Know, for Search'}
# c:\Users\omar_\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'astrolastic.francecentral.cloudapp.azure.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
es.indices.delete(index="neurone")
# Out:
# c:\Users\omar_\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'astrolastic.francecentral.cloudapp.azure.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ObjectApiResponse({'acknowledged': True})

# %%
index_name = "neurone"
settings = {
    "settings": {
        "number_of_shards": 1,
        "number_of_replicas": 0,
        "analysis": {
              "analyzer": {
                "custom_fr_analyzer": {
                  "type": "custom",
                  "tokenizer": "standard",
                  "filter": [
                    "lowercase",
                    "asciifolding",
                    "french_stop",
                    "french_stemmer"
                  ]
                }
              },
              "filter": {
                "french_stop": {
                  "type": "stop",
                  "stopwords": "_french_"
                },
                "french_stemmer": {
                  "type": "stemmer",
                  "language": "french"
                    }
                }
          

        }
    },
    "mappings": {
        "properties": {
            "text": {"type": "text", "analyzer": "custom_fr_analyzer"}
        }
    }
}


es.indices.create(index=index_name, body=settings)
# Out:
# c:\Users\omar_\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'astrolastic.francecentral.cloudapp.azure.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'neurone'})

# %%
corpus = [
    "Le cerveau humain contient environ 86 milliards de neurones.",
    "Les neurones communiquent entre eux grâce aux synapses et aux neurotransmetteurs.",
    "La plasticité cérébrale permet au cerveau de s'adapter aux expériences et à l'apprentissage.",
    "Les neurotransmetteurs comme la dopamine influencent l'humeur, la motivation et la mémoire.",
    "L'hippocampe joue un rôle clé dans la formation des souvenirs et la mémoire du cerveau.",
    "Les neurones moteurs transmettent les signaux du cerveau aux muscles et aux organes.",
    "La mémoire à court terme dépend fortement du cortex préfrontal et de l'activité neuronale.",
    "Les synapses excitatrices et inhibitrices régulent l'activité des neurones et la communication cérébrale.",
    "La dopamine est essentielle pour le système de récompense du cerveau et pour l'apprentissage.",
    "Les circuits neuronaux peuvent se réorganiser après une lésion cérébrale ou des traumatismes.",
    "Le cortex visuel et le cortex préfrontal sont responsables du traitement des informations visuelles et cognitives.",
    "Les axones permettent de transmettre les signaux électriques sur de longues distances entre neurones.",
    "La plasticité synaptique est la base de l'apprentissage, de la mémoire et de la communication neuronale.",
    "Les neurones sensoriels détectent les stimuli environnementaux et transmettent l'information au cerveau.",
    "Le cerveau droit et le cerveau gauche ont des fonctions complémentaires dans le traitement des informations.",
    "La sérotonine et la dopamine régulent l'humeur, le sommeil, l'appétit et la motivation.",
    "Les dendrites reçoivent les signaux des autres neurones et participent à la plasticité cérébrale.",
    "Les maladies neurodégénératives affectent la structure et la fonction des neurones et des synapses.",
    "L'amygdale est impliquée dans les émotions, la peur et le traitement des souvenirs.",
    "L'axone et la dendrite sont des structures essentielles pour la communication neuronale et la transmission des signaux."
]

docs = [{"_id": i, "_source":{"text": corpus[i]}, "_index":"neurone" } for i in range(len(corpus))]
helpers.bulk(es, docs)
# Out:
# c:\Users\omar_\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'astrolastic.francecentral.cloudapp.azure.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# (20, [])

# %%
query = {
    "query": {
        "match": {"text": "cerveau"}
    }
}

result = es.search(index="neurone", body=query)
for hit in result["hits"]["hits"]:
    print(hit["_id"], hit["_source"])
# Out:
# 14 {'text': 'Le cerveau droit et le cerveau gauche ont des fonctions complémentaires dans le traitement des informations.'}
# 0 {'text': 'Le cerveau humain contient environ 86 milliards de neurones.'}
# 5 {'text': 'Les neurones moteurs transmettent les signaux du cerveau aux muscles et aux organes.'}
# 8 {'text': "La dopamine est essentielle pour le système de récompense du cerveau et pour l'apprentissage."}
# 2 {'text': "La plasticité cérébrale permet au cerveau de s'adapter aux expériences et à l'apprentissage."}
# 4 {'text': "L'hippocampe joue un rôle clé dans la formation des souvenirs et la mémoire du cerveau."}
# 13 {'text': "Les neurones sensoriels détectent les stimuli environnementaux et transmettent l'information au cerveau."}
# ...

# %%
analysis = es.indices.analyze(
    index="neurone",
    body={"analyzer": "custom_fr_analyzer", "text": "Les neurones sensoriels détectent les stimuli environnementaux et transmettent l'information au cerveau"}
)
print([token["token"] for token in analysis["tokens"]])
# Out:
# ['neuron', 'sensoriel', 'detectent', 'stimul', 'environnemental', 'transmettent', "l'inform", 'cerveau']
# c:\Users\omar_\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'astrolastic.francecentral.cloudapp.azure.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
stats = es.indices.stats(index="neurone")
# Out:
# c:\Users\omar_\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'astrolastic.francecentral.cloudapp.azure.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
print(stats['_all'])
# Out:
# {'primaries': {'docs': {'count': 20, 'deleted': 0, 'total_size_in_bytes': 7614}, 'shard_stats': {'total_count': 1}, 'store': {'size_in_bytes': 7841, 'total_data_set_size_in_bytes': 7841, 'reserved_in_bytes': 0}, 'indexing': {'index_total': 20, 'index_time_in_millis': 7, 'index_current': 0, 'index_failed': 0, 'index_failed_due_to_version_conflict': 0, 'delete_total': 0, 'delete_time_in_millis': 0, 'delete_current': 0, 'noop_update_total': 0, 'is_throttled': False, 'throttle_time_in_millis': 0, 'write_load': 4.106331680844247e-05, 'recent_write_load': 3.338332068682849e-05, 'peak_write_load': 6.840441691563083e-05}, 'get': {'total': 0, 'time_in_millis': 0, 'exists_total': 0, 'exists_time_in_millis': 0, 'missing_total': 0, 'missing_time_in_millis': 0, 'current': 0}, 'search': {'open_contexts': 0, 'query_total': 1, 'query_time_in_millis': 0, 'query_current': 0, 'query_failure': 0, 'fetch_total': 1, 'fetch_time_in_millis': 0, 'fetch_current': 0, 'fetch_failure': 0, 'scroll_total': 0, 'scr
# ...

# %% [markdown]
# ```json
# {
#   "primaries": {
#     "docs": { "count": 20, "deleted": 0, "total_size_in_bytes": 7614 },
#     "shard_stats": { "total_count": 1 },
#     "store": {
#       "size_in_bytes": 7841,
#       "total_data_set_size_in_bytes": 7841,
#       "reserved_in_bytes": 0
#     },
#     "indexing": {
#       "index_total": 20,
#       "index_time_in_millis": 7,
#       "index_current": 0,
#       "index_failed": 0,
#       "index_failed_due_to_version_conflict": 0,
#       "delete_total": 0,
#       "delete_time_in_millis": 0,
#       "delete_current": 0,
#       "noop_update_total": 0,
#       "is_throttled": false,
#       "throttle_time_in_millis": 0,
#       "write_load": 4.106331680844247e-5,
#       "recent_write_load": 3.338332068682849e-5,
#       "peak_write_load": 6.840441691563083e-5
#     },
#     "get": {
#       "total": 0,
#       "time_in_millis": 0,
#       "exists_total": 0,
#       "exists_time_in_millis": 0,
#       "missing_total": 0,
#       "missing_time_in_millis": 0,
#       "current": 0
#     },
#     "search": {
#       "open_contexts": 0,
#       "query_total": 1,
#       "query_time_in_millis": 0,
#       "query_current": 0,
#       "query_failure": 0,
#       "fetch_total": 1,
#       "fetch_time_in_millis": 0,
#       "fetch_current": 0,
#       "fetch_failure": 0,
#       "scroll_total": 0,
#       "scroll_time_in_millis": 0,
#       "scroll_current": 0,
#       "suggest_total": 0,
#       "suggest_time_in_millis": 0,
#       "suggest_current": 0,
#       "recent_search_load": 5.314826873813598e-6
#     },
#     "merges": {
#       "current": 0,
#       "current_docs": 0,
#       "current_size_in_bytes": 0,
#       "total": 0,
#       "total_time_in_millis": 0,
#       "total_docs": 0,
#       "total_size_in_bytes": 0,
#       "total_stopped_time_in_millis": 0,
#       "total_throttled_time_in_millis": 0,
#       "total_auto_throttle_in_bytes": 20971520
#     },
#     "refresh": {
#       "total": 3,
#       "total_time_in_millis": 9,
#       "external_total": 3,
#       "external_total_time_in_millis": 9,
#       "listeners": 0
#     },
#     "flush": {
#       "total": 0,
#       "periodic": 0,
#       "total_time_in_millis": 0,
#       "total_time_excluding_waiting_on_lock_in_millis": 0
#     },
#     "warmer": { "current": 0, "total": 2, "total_time_in_millis": 0 },
#     "query_cache": {
#       "memory_size_in_bytes": 0,
#       "total_count": 0,
#       "hit_count": 0,
#       "miss_count": 0,
#       "cache_size": 0,
#       "cache_count": 0,
#       "evictions": 0
#     },
#     "fielddata": {
#       "memory_size_in_bytes": 0,
#       "evictions": 0,
#       "global_ordinals": { "build_time_in_millis": 0 }
#     },
#     "completion": { "size_in_bytes": 0 },
#     "segments": {
#       "count": 1,
#       "memory_in_bytes": 0,
#       "terms_memory_in_bytes": 0,
#       "stored_fields_memory_in_bytes": 0,
#       "term_vectors_memory_in_bytes": 0,
#       "norms_memory_in_bytes": 0,
#       "points_memory_in_bytes": 0,
#       "doc_values_memory_in_bytes": 0,
#       "index_writer_memory_in_bytes": 0,
#       "version_map_memory_in_bytes": 0,
#       "fixed_bit_set_memory_in_bytes": 0,
#       "max_unsafe_auto_id_timestamp": -1,
#       "file_sizes": {}
#     },
#     "translog": {
#       "operations": 20,
#       "size_in_bytes": 3143,
#       "uncommitted_operations": 20,
#       "uncommitted_size_in_bytes": 3143,
#       "earliest_last_modified_age": 176681
#     },
#     "request_cache": {
#       "memory_size_in_bytes": 0,
#       "evictions": 0,
#       "hit_count": 0,
#       "miss_count": 0
#     },
#     "recovery": {
#       "current_as_source": 0,
#       "current_as_target": 0,
#       "throttle_time_in_millis": 0
#     },
#     "bulk": {
#       "total_operations": 1,
#       "total_time_in_millis": 8,
#       "total_size_in_bytes": 2157,
#       "avg_time_in_millis": 0,
#       "avg_size_in_bytes": 215
#     },
#     "dense_vector": {
#       "value_count": 0,
#       "off_heap": {
#         "total_size_bytes": 0,
#         "total_veb_size_bytes": 0,
#         "total_vec_size_bytes": 0,
#         "total_veq_size_bytes": 0,
#         "total_vex_size_bytes": 0
#       }
#     },
#     "sparse_vector": { "value_count": 0 }
#   },
#   "total": {
#     "docs": { "count": 20, "deleted": 0, "total_size_in_bytes": 7614 },
#     "shard_stats": { "total_count": 1 },
#     "store": {
#       "size_in_bytes": 7841,
#       "total_data_set_size_in_bytes": 7841,
#       "reserved_in_bytes": 0
#     },
#     "indexing": {
#       "index_total": 20,
#       "index_time_in_millis": 7,
#       "index_current": 0,
#       "index_failed": 0,
#       "index_failed_due_to_version_conflict": 0,
#       "delete_total": 0,
#       "delete_time_in_millis": 0,
#       "delete_current": 0,
#       "noop_update_total": 0,
#       "is_throttled": false,
#       "throttle_time_in_millis": 0,
#       "write_load": 4.106331680844247e-5,
#       "recent_write_load": 3.338332068682849e-5,
#       "peak_write_load": 6.840441691563083e-5
#     },
#     "get": {
#       "total": 0,
#       "time_in_millis": 0,
#       "exists_total": 0,
#       "exists_time_in_millis": 0,
#       "missing_total": 0,
#       "missing_time_in_millis": 0,
#       "current": 0
#     },
#     "search": {
#       "open_contexts": 0,
#       "query_total": 1,
#       "query_time_in_millis": 0,
#       "query_current": 0,
#       "query_failure": 0,
#       "fetch_total": 1,
#       "fetch_time_in_millis": 0,
#       "fetch_current": 0,
#       "fetch_failure": 0,
#       "scroll_total": 0,
#       "scroll_time_in_millis": 0,
#       "scroll_current": 0,
#       "suggest_total": 0,
#       "suggest_time_in_millis": 0,
#       "suggest_current": 0,
#       "recent_search_load": 5.314826873813598e-6
#     },
#     "merges": {
#       "current": 0,
#       "current_docs": 0,
#       "current_size_in_bytes": 0,
#       "total": 0,
#       "total_time_in_millis": 0,
#       "total_docs": 0,
#       "total_size_in_bytes": 0,
#       "total_stopped_time_in_millis": 0,
#       "total_throttled_time_in_millis": 0,
#       "total_auto_throttle_in_bytes": 20971520
#     },
#     "refresh": {
#       "total": 3,
#       "total_time_in_millis": 9,
#       "external_total": 3,
#       "external_total_time_in_millis": 9,
#       "listeners": 0
#     },
#     "flush": {
#       "total": 0,
#       "periodic": 0,
#       "total_time_in_millis": 0,
#       "total_time_excluding_waiting_on_lock_in_millis": 0
#     },
#     "warmer": { "current": 0, "total": 2, "total_time_in_millis": 0 },
#     "query_cache": {
#       "memory_size_in_bytes": 0,
#       "total_count": 0,
#       "hit_count": 0,
#       "miss_count": 0,
#       "cache_size": 0,
#       "cache_count": 0,
#       "evictions": 0
#     },
#     "fielddata": {
#       "memory_size_in_bytes": 0,
#       "evictions": 0,
#       "global_ordinals": { "build_time_in_millis": 0 }
#     },
#     "completion": { "size_in_bytes": 0 },
#     "segments": {
#       "count": 1,
#       "memory_in_bytes": 0,
#       "terms_memory_in_bytes": 0,
#       "stored_fields_memory_in_bytes": 0,
#       "term_vectors_memory_in_bytes": 0,
#       "norms_memory_in_bytes": 0,
#       "points_memory_in_bytes": 0,
#       "doc_values_memory_in_bytes": 0,
#       "index_writer_memory_in_bytes": 0,
#       "version_map_memory_in_bytes": 0,
#       "fixed_bit_set_memory_in_bytes": 0,
#       "max_unsafe_auto_id_timestamp": -1,
#       "file_sizes": {}
#     },
#     "translog": {
#       "operations": 20,
#       "size_in_bytes": 3143,
#       "uncommitted_operations": 20,
#       "uncommitted_size_in_bytes": 3143,
#       "earliest_last_modified_age": 176681
#     },
#     "request_cache": {
#       "memory_size_in_bytes": 0,
#       "evictions": 0,
#       "hit_count": 0,
#       "miss_count": 0
#     },
#     "recovery": {
#       "current_as_source": 0,
#       "current_as_target": 0,
#       "throttle_time_in_millis": 0
#     },
#     "bulk": {
#       "total_operations": 1,
#       "total_time_in_millis": 8,
#       "total_size_in_bytes": 2157,
#       "avg_time_in_millis": 0,
#       "avg_size_in_bytes": 215
#     },
#     "dense_vector": {
#       "value_count": 0,
#       "off_heap": {
#         "total_size_bytes": 0,
#         "total_veb_size_bytes": 0,
#         "total_vec_size_bytes": 0,
#         "total_veq_size_bytes": 0,
#         "total_vex_size_bytes": 0
#       }
#     },
#     "sparse_vector": { "value_count": 0 }
#   }
# }
# ```

# %%
segments = es.indices.segments(index="neurone")
print(segments)
# Out:
# {'_shards': {'total': 1, 'successful': 1, 'failed': 0}, 'indices': {'neurone': {'shards': {'0': [{'routing': {'state': 'STARTED', 'primary': True, 'node': 'IUtKulAwT_O8Dw6yHaqUlw'}, 'num_committed_segments': 0, 'num_search_segments': 1, 'segments': {'_0': {'generation': 0, 'num_docs': 20, 'deleted_docs': 0, 'size_in_bytes': 7614, 'committed': False, 'search': True, 'version': '10.3.2', 'compound': True, 'attributes': {'Lucene90StoredFieldsFormat.mode': 'BEST_SPEED'}}}}]}}}}
# c:\Users\omar_\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'astrolastic.francecentral.cloudapp.azure.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %% [markdown]
# the most important highlights
#     "docs": { "count": 20, "deleted": 0, "total_size_in_bytes": 7614 },
#     "shard_stats": { "total_count": 1 },
#     "store": {
#       "size_in_bytes": 7841,
#       "total_data_set_size_in_bytes": 7841,
#       "reserved_in_bytes": 0
#     },
#     "indexing": {
#       "index_total": 20,
#       "index_time_in_millis": 7,...}

# %% [markdown]
# ```json
# {
#   "_shards": { "total": 1, "successful": 1, "failed": 0 },
#   "indices": {
#     "neurone": {
#       "shards": {
#         "0": [
#           {
#             "routing": {
#               "state": "STARTED",
#               "primary": true,
#               "node": "IUtKulAwT_O8Dw6yHaqUlw"
#             },
#             "num_committed_segments": 0,
#             "num_search_segments": 1,
#             "segments": {
#               "_0": {
#                 "generation": 0,
#                 "num_docs": 20,
#                 "deleted_docs": 0,
#                 "size_in_bytes": 7614,
#                 "committed": false,
#                 "search": true,
#                 "version": "10.3.2",
#                 "compound": true,
#                 "attributes": {
#                   "Lucene90StoredFieldsFormat.mode": "BEST_SPEED"
#                 }
#               }
#             }
#           }
#         ]
#       }
#     }
#   }
# }
# ```

# %%
index_name_2 = "neurone_2"
settings = {
    "settings": {   
        "number_of_shards": 2,
        "number_of_replicas": 0,
        "analysis": {
              "analyzer": {
                "custom_fr_analyzer": {
                  "type": "custom",
                  "tokenizer": "standard",
                  "filter": [
                    "lowercase",
                    "asciifolding",
                    "french_stop",
                    "french_stemmer"
                  ]
                }
              },
              "filter": {
                "french_stop": {
                  "type": "stop",
                  "stopwords": "_french_"
                },
                "french_stemmer": {
                  "type": "stemmer",
                  "language": "french"
                    }
                }
          

        }
    },
    "mappings": {
        "properties": {
            "text": {"type": "text", "analyzer": "custom_fr_analyzer"}
        }
    }
}


es.indices.create(index=index_name_2, body=settings)
# Out:
# c:\Users\omar_\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'astrolastic.francecentral.cloudapp.azure.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'neurone_2'})

# %%
docs_2 = [{"_id": i, "_source":{"text": corpus[i]}, "_index":"neurone_2" } for i in range(len(corpus))]
helpers.bulk(es, docs_2)
# Out:
# c:\Users\omar_\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'astrolastic.francecentral.cloudapp.azure.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# (20, [])

# %%
stats_2 = es.indices.stats(index="neurone_2")
print(stats_2 )
# Out:
# {'_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_all': {'primaries': {'docs': {'count': 20, 'deleted': 0, 'total_size_in_bytes': 12147}, 'shard_stats': {'total_count': 2}, 'store': {'size_in_bytes': 12815, 'total_data_set_size_in_bytes': 12815, 'reserved_in_bytes': 0}, 'indexing': {'index_total': 20, 'index_time_in_millis': 12, 'index_current': 0, 'index_failed': 0, 'index_failed_due_to_version_conflict': 0, 'delete_total': 0, 'delete_time_in_millis': 0, 'delete_current': 0, 'noop_update_total': 0, 'is_throttled': False, 'throttle_time_in_millis': 0, 'write_load': 1.2690573827206521e-05, 'recent_write_load': 7.448666246817531e-06, 'peak_write_load': 1.7822863444871113e-05}, 'get': {'total': 0, 'time_in_millis': 0, 'exists_total': 0, 'exists_time_in_millis': 0, 'missing_total': 0, 'missing_time_in_millis': 0, 'current': 0}, 'search': {'open_contexts': 0, 'query_total': 0, 'query_time_in_millis': 0, 'query_current': 0, 'query_failure': 0, 'fetch_total': 0, 'fetch_time_in_milli
# ...

# %% [markdown]
# ```json
# {
#   "_shards": { "total": 2, "successful": 2, "failed": 0 },
#   "_all": {
#     "primaries": {
#       "docs": { "count": 20, "deleted": 0, "total_size_in_bytes": 12147 },
#       "shard_stats": { "total_count": 2 },
#       "store": {
#         "size_in_bytes": 12815,
#         "total_data_set_size_in_bytes": 12815,
#         "reserved_in_bytes": 0
#       },
#       "indexing": {
#         "index_total": 20,
#         "index_time_in_millis": 12,
#         "index_current": 0,
#         "index_failed": 0,
#         "index_failed_due_to_version_conflict": 0,
#         "delete_total": 0,
#         "delete_time_in_millis": 0,
#         "delete_current": 0,
#         "noop_update_total": 0,
#         "is_throttled": false,
#         "throttle_time_in_millis": 0,
#         "write_load": 1.2690573827206521e-5,
#         "recent_write_load": 7.448666246817531e-6,
#         "peak_write_load": 1.7822863444871113e-5
#       },
#       "get": {
#         "total": 0,
#         "time_in_millis": 0,
#         "exists_total": 0,
#         "exists_time_in_millis": 0,
#         "missing_total": 0,
#         "missing_time_in_millis": 0,
#         "current": 0
#       },
#       "search": {
#         "open_contexts": 0,
#         "query_total": 0,
#         "query_time_in_millis": 0,
#         "query_current": 0,
#         "query_failure": 0,
#         "fetch_total": 0,
#         "fetch_time_in_millis": 0,
#         "fetch_current": 0,
#         "fetch_failure": 0,
#         "scroll_total": 0,
#         "scroll_time_in_millis": 0,
#         "scroll_current": 0,
#         "suggest_total": 0,
#         "suggest_time_in_millis": 0,
#         "suggest_current": 0,
#         "recent_search_load": 0.0
#       },
#       "merges": {
#         "current": 0,
#         "current_docs": 0,
#         "current_size_in_bytes": 0,
#         "total": 0,
#         "total_time_in_millis": 0,
#         "total_docs": 0,
#         "total_size_in_bytes": 0,
#         "total_stopped_time_in_millis": 0,
#         "total_throttled_time_in_millis": 0,
#         "total_auto_throttle_in_bytes": 41943040
#       },
#       "refresh": {
#         "total": 8,
#         "total_time_in_millis": 0,
#         "external_total": 6,
#         "external_total_time_in_millis": 0,
#         "listeners": 0
#       },
#       "flush": {
#         "total": 2,
#         "periodic": 2,
#         "total_time_in_millis": 121,
#         "total_time_excluding_waiting_on_lock_in_millis": 121
#       },
#       "warmer": { "current": 0, "total": 4, "total_time_in_millis": 0 },
#       "query_cache": {
#         "memory_size_in_bytes": 0,
#         "total_count": 0,
#         "hit_count": 0,
#         "miss_count": 0,
#         "cache_size": 0,
#         "cache_count": 0,
#         "evictions": 0
#       },
#       "fielddata": {
#         "memory_size_in_bytes": 0,
#         "evictions": 0,
#         "global_ordinals": { "build_time_in_millis": 0 }
#       },
#       "completion": { "size_in_bytes": 0 },
#       "segments": {
#         "count": 2,
#         "memory_in_bytes": 0,
#         "terms_memory_in_bytes": 0,
#         "stored_fields_memory_in_bytes": 0,
#         "term_vectors_memory_in_bytes": 0,
#         "norms_memory_in_bytes": 0,
#         "points_memory_in_bytes": 0,
#         "doc_values_memory_in_bytes": 0,
#         "index_writer_memory_in_bytes": 0,
#         "version_map_memory_in_bytes": 0,
#         "fixed_bit_set_memory_in_bytes": 0,
#         "max_unsafe_auto_id_timestamp": -1,
#         "file_sizes": {}
#       },
#       "translog": {
#         "operations": 0,
#         "size_in_bytes": 110,
#         "uncommitted_operations": 0,
#         "uncommitted_size_in_bytes": 110,
#         "earliest_last_modified_age": 157048
#       },
#       "request_cache": {
#         "memory_size_in_bytes": 0,
#         "evictions": 0,
#         "hit_count": 0,
#         "miss_count": 0
#       },
#       "recovery": {
#         "current_as_source": 0,
#         "current_as_target": 0,
#         "throttle_time_in_millis": 0
#       },
#       "bulk": {
#         "total_operations": 2,
#         "total_time_in_millis": 12,
#         "total_size_in_bytes": 2157,
#         "avg_time_in_millis": 0,
#         "avg_size_in_bytes": 107
#       },
#       "dense_vector": {
#         "value_count": 0,
#         "off_heap": {
#           "total_size_bytes": 0,
#           "total_veb_size_bytes": 0,
#           "total_vec_size_bytes": 0,
#           "total_veq_size_bytes": 0,
#           "total_vex_size_bytes": 0
#         }
#       },
#       "sparse_vector": { "value_count": 0 }
#     },
#     "total": {
#       "docs": { "count": 20, "deleted": 0, "total_size_in_bytes": 12147 },
#       "shard_stats": { "total_count": 2 },
#       "store": {
#         "size_in_bytes": 12815,
#         "total_data_set_size_in_bytes": 12815,
#         "reserved_in_bytes": 0
#       },
#       "indexing": {
#         "index_total": 20,
#         "index_time_in_millis": 12,
#         "index_current": 0,
#         "index_failed": 0,
#         "index_failed_due_to_version_conflict": 0,
#         "delete_total": 0,
#         "delete_time_in_millis": 0,
#         "delete_current": 0,
#         "noop_update_total": 0,
#         "is_throttled": false,
#         "throttle_time_in_millis": 0,
#         "write_load": 1.2690573827206521e-5,
#         "recent_write_load": 7.448666246817531e-6,
#         "peak_write_load": 1.7822863444871113e-5
#       },
#       "get": {
#         "total": 0,
#         "time_in_millis": 0,
#         "exists_total": 0,
#         "exists_time_in_millis": 0,
#         "missing_total": 0,
#         "missing_time_in_millis": 0,
#         "current": 0
#       },
#       "search": {
#         "open_contexts": 0,
#         "query_total": 0,
#         "query_time_in_millis": 0,
#         "query_current": 0,
#         "query_failure": 0,
#         "fetch_total": 0,
#         "fetch_time_in_millis": 0,
#         "fetch_current": 0,
#         "fetch_failure": 0,
#         "scroll_total": 0,
#         "scroll_time_in_millis": 0,
#         "scroll_current": 0,
#         "suggest_total": 0,
#         "suggest_time_in_millis": 0,
#         "suggest_current": 0,
#         "recent_search_load": 0.0
#       },
#       "merges": {
#         "current": 0,
#         "current_docs": 0,
#         "current_size_in_bytes": 0,
#         "total": 0,
#         "total_time_in_millis": 0,
#         "total_docs": 0,
#         "total_size_in_bytes": 0,
#         "total_stopped_time_in_millis": 0,
#         "total_throttled_time_in_millis": 0,
#         "total_auto_throttle_in_bytes": 41943040
#       },
#       "refresh": {
#         "total": 8,
#         "total_time_in_millis": 0,
#         "external_total": 6,
#         "external_total_time_in_millis": 0,
#         "listeners": 0
#       },
#       "flush": {
#         "total": 2,
#         "periodic": 2,
#         "total_time_in_millis": 121,
#         "total_time_excluding_waiting_on_lock_in_millis": 121
#       },
#       "warmer": { "current": 0, "total": 4, "total_time_in_millis": 0 },
#       "query_cache": {
#         "memory_size_in_bytes": 0,
#         "total_count": 0,
#         "hit_count": 0,
#         "miss_count": 0,
#         "cache_size": 0,
#         "cache_count": 0,
#         "evictions": 0
#       },
#       "fielddata": {
#         "memory_size_in_bytes": 0,
#         "evictions": 0,
#         "global_ordinals": { "build_time_in_millis": 0 }
#       },
#       "completion": { "size_in_bytes": 0 },
#       "segments": {
#         "count": 2,
#         "memory_in_bytes": 0,
#         "terms_memory_in_bytes": 0,
#         "stored_fields_memory_in_bytes": 0,
#         "term_vectors_memory_in_bytes": 0,
#         "norms_memory_in_bytes": 0,
#         "points_memory_in_bytes": 0,
#         "doc_values_memory_in_bytes": 0,
#         "index_writer_memory_in_bytes": 0,
#         "version_map_memory_in_bytes": 0,
#         "fixed_bit_set_memory_in_bytes": 0,
#         "max_unsafe_auto_id_timestamp": -1,
#         "file_sizes": {}
#       },
#       "translog": {
#         "operations": 0,
#         "size_in_bytes": 110,
#         "uncommitted_operations": 0,
#         "uncommitted_size_in_bytes": 110,
#         "earliest_last_modified_age": 157048
#       },
#       "request_cache": {
#         "memory_size_in_bytes": 0,
#         "evictions": 0,
#         "hit_count": 0,
#         "miss_count": 0
#       },
#       "recovery": {
#         "current_as_source": 0,
#         "current_as_target": 0,
#         "throttle_time_in_millis": 0
#       },
#       "bulk": {
#         "total_operations": 2,
#         "total_time_in_millis": 12,
#         "total_size_in_bytes": 2157,
#         "avg_time_in_millis": 0,
#         "avg_size_in_bytes": 107
#       },
#       "dense_vector": {
#         "value_count": 0,
#         "off_heap": {
#           "total_size_bytes": 0,
#           "total_veb_size_bytes": 0,
#           "total_vec_size_bytes": 0,
#           "total_veq_size_bytes": 0,
#           "total_vex_size_bytes": 0
#         }
#       },
#       "sparse_vector": { "value_count": 0 }
#     }
#   },
#   "indices": {
#     "neurone_2": {
#       "uuid": "UPN3F1roTxiow3u7t-YPag",
#       "health": "green",
#       "status": "open",
#       "primaries": {
#         "docs": { "count": 20, "deleted": 0, "total_size_in_bytes": 12147 },
#         "shard_stats": { "total_count": 2 },
#         "store": {
#           "size_in_bytes": 12815,
#           "total_data_set_size_in_bytes": 12815,
#           "reserved_in_bytes": 0
#         },
#         "indexing": {
#           "index_total": 20,
#           "index_time_in_millis": 12,
#           "index_current": 0,
#           "index_failed": 0,
#           "index_failed_due_to_version_conflict": 0,
#           "delete_total": 0,
#           "delete_time_in_millis": 0,
#           "delete_current": 0,
#           "noop_update_total": 0,
#           "is_throttled": false,
#           "throttle_time_in_millis": 0,
#           "write_load": 1.2690573827206521e-5,
#           "recent_write_load": 7.448666246817531e-6,
#           "peak_write_load": 1.7822863444871113e-5
#         },
#         "get": {
#           "total": 0,
#           "time_in_millis": 0,
#           "exists_total": 0,
#           "exists_time_in_millis": 0,
#           "missing_total": 0,
#           "missing_time_in_millis": 0,
#           "current": 0
#         },
#         "search": {
#           "open_contexts": 0,
#           "query_total": 0,
#           "query_time_in_millis": 0,
#           "query_current": 0,
#           "query_failure": 0,
#           "fetch_total": 0,
#           "fetch_time_in_millis": 0,
#           "fetch_current": 0,
#           "fetch_failure": 0,
#           "scroll_total": 0,
#           "scroll_time_in_millis": 0,
#           "scroll_current": 0,
#           "suggest_total": 0,
#           "suggest_time_in_millis": 0,
#           "suggest_current": 0,
#           "recent_search_load": 0.0
#         },
#         "merges": {
#           "current": 0,
#           "current_docs": 0,
#           "current_size_in_bytes": 0,
#           "total": 0,
#           "total_time_in_millis": 0,
#           "total_docs": 0,
#           "total_size_in_bytes": 0,
#           "total_stopped_time_in_millis": 0,
#           "total_throttled_time_in_millis": 0,
#           "total_auto_throttle_in_bytes": 41943040
#         },
#         "refresh": {
#           "total": 8,
#           "total_time_in_millis": 0,
#           "external_total": 6,
#           "external_total_time_in_millis": 0,
#           "listeners": 0
#         },
#         "flush": {
#           "total": 2,
#           "periodic": 2,
#           "total_time_in_millis": 121,
#           "total_time_excluding_waiting_on_lock_in_millis": 121
#         },
#         "warmer": { "current": 0, "total": 4, "total_time_in_millis": 0 },
#         "query_cache": {
#           "memory_size_in_bytes": 0,
#           "total_count": 0,
#           "hit_count": 0,
#           "miss_count": 0,
#           "cache_size": 0,
#           "cache_count": 0,
#           "evictions": 0
#         },
#         "fielddata": {
#           "memory_size_in_bytes": 0,
#           "evictions": 0,
#           "global_ordinals": { "build_time_in_millis": 0 }
#         },
#         "completion": { "size_in_bytes": 0 },
#         "segments": {
#           "count": 2,
#           "memory_in_bytes": 0,
#           "terms_memory_in_bytes": 0,
#           "stored_fields_memory_in_bytes": 0,
#           "term_vectors_memory_in_bytes": 0,
#           "norms_memory_in_bytes": 0,
#           "points_memory_in_bytes": 0,
#           "doc_values_memory_in_bytes": 0,
#           "index_writer_memory_in_bytes": 0,
#           "version_map_memory_in_bytes": 0,
#           "fixed_bit_set_memory_in_bytes": 0,
#           "max_unsafe_auto_id_timestamp": -1,
#           "file_sizes": {}
#         },
#         "translog": {
#           "operations": 0,
#           "size_in_bytes": 110,
#           "uncommitted_operations": 0,
#           "uncommitted_size_in_bytes": 110,
#           "earliest_last_modified_age": 157048
#         },
#         "request_cache": {
#           "memory_size_in_bytes": 0,
#           "evictions": 0,
#           "hit_count": 0,
#           "miss_count": 0
#         },
#         "recovery": {
#           "current_as_source": 0,
#           "current_as_target": 0,
#           "throttle_time_in_millis": 0
#         },
#         "bulk": {
#           "total_operations": 2,
#           "total_time_in_millis": 12,
#           "total_size_in_bytes": 2157,
#           "avg_time_in_millis": 0,
#           "avg_size_in_bytes": 107
#         },
#         "dense_vector": {
#           "value_count": 0,
#           "off_heap": {
#             "total_size_bytes": 0,
#             "total_veb_size_bytes": 0,
#             "total_vec_size_bytes": 0,
#             "total_veq_size_bytes": 0,
#             "total_vex_size_bytes": 0
#           }
#         },
#         "sparse_vector": { "value_count": 0 }
#       },
#       "total": {
#         "docs": { "count": 20, "deleted": 0, "total_size_in_bytes": 12147 },
#         "shard_stats": { "total_count": 2 },
#         "store": {
#           "size_in_bytes": 12815,
#           "total_data_set_size_in_bytes": 12815,
#           "reserved_in_bytes": 0
#         },
#         "indexing": {
#           "index_total": 20,
#           "index_time_in_millis": 12,
#           "index_current": 0,
#           "index_failed": 0,
#           "index_failed_due_to_version_conflict": 0,
#           "delete_total": 0,
#           "delete_time_in_millis": 0,
#           "delete_current": 0,
#           "noop_update_total": 0,
#           "is_throttled": false,
#           "throttle_time_in_millis": 0,
#           "write_load": 1.2690573827206521e-5,
#           "recent_write_load": 7.448666246817531e-6,
#           "peak_write_load": 1.7822863444871113e-5
#         },
#         "get": {
#           "total": 0,
#           "time_in_millis": 0,
#           "exists_total": 0,
#           "exists_time_in_millis": 0,
#           "missing_total": 0,
#           "missing_time_in_millis": 0,
#           "current": 0
#         },
#         "search": {
#           "open_contexts": 0,
#           "query_total": 0,
#           "query_time_in_millis": 0,
#           "query_current": 0,
#           "query_failure": 0,
#           "fetch_total": 0,
#           "fetch_time_in_millis": 0,
#           "fetch_current": 0,
#           "fetch_failure": 0,
#           "scroll_total": 0,
#           "scroll_time_in_millis": 0,
#           "scroll_current": 0,
#           "suggest_total": 0,
#           "suggest_time_in_millis": 0,
#           "suggest_current": 0,
#           "recent_search_load": 0.0
#         },
#         "merges": {
#           "current": 0,
#           "current_docs": 0,
#           "current_size_in_bytes": 0,
#           "total": 0,
#           "total_time_in_millis": 0,
#           "total_docs": 0,
#           "total_size_in_bytes": 0,
#           "total_stopped_time_in_millis": 0,
#           "total_throttled_time_in_millis": 0,
#           "total_auto_throttle_in_bytes": 41943040
#         },
#         "refresh": {
#           "total": 8,
#           "total_time_in_millis": 0,
#           "external_total": 6,
#           "external_total_time_in_millis": 0,
#           "listeners": 0
#         },
#         "flush": {
#           "total": 2,
#           "periodic": 2,
#           "total_time_in_millis": 121,
#           "total_time_excluding_waiting_on_lock_in_millis": 121
#         },
#         "warmer": { "current": 0, "total": 4, "total_time_in_millis": 0 },
#         "query_cache": {
#           "memory_size_in_bytes": 0,
#           "total_count": 0,
#           "hit_count": 0,
#           "miss_count": 0,
#           "cache_size": 0,
#           "cache_count": 0,
#           "evictions": 0
#         },
#         "fielddata": {
#           "memory_size_in_bytes": 0,
#           "evictions": 0,
#           "global_ordinals": { "build_time_in_millis": 0 }
#         },
#         "completion": { "size_in_bytes": 0 },
#         "segments": {
#           "count": 2,
#           "memory_in_bytes": 0,
#           "terms_memory_in_bytes": 0,
#           "stored_fields_memory_in_bytes": 0,
#           "term_vectors_memory_in_bytes": 0,
#           "norms_memory_in_bytes": 0,
#           "points_memory_in_bytes": 0,
#           "doc_values_memory_in_bytes": 0,
#           "index_writer_memory_in_bytes": 0,
#           "version_map_memory_in_bytes": 0,
#           "fixed_bit_set_memory_in_bytes": 0,
#           "max_unsafe_auto_id_timestamp": -1,
#           "file_sizes": {}
#         },
#         "translog": {
#           "operations": 0,
#           "size_in_bytes": 110,
#           "uncommitted_operations": 0,
#           "uncommitted_size_in_bytes": 110,
#           "earliest_last_modified_age": 157048
#         },
#         "request_cache": {
#           "memory_size_in_bytes": 0,
#           "evictions": 0,
#           "hit_count": 0,
#           "miss_count": 0
#         },
#         "recovery": {
#           "current_as_source": 0,
#           "current_as_target": 0,
#           "throttle_time_in_millis": 0
#         },
#         "bulk": {
#           "total_operations": 2,
#           "total_time_in_millis": 12,
#           "total_size_in_bytes": 2157,
#           "avg_time_in_millis": 0,
#           "avg_size_in_bytes": 107
#         },
#         "dense_vector": {
#           "value_count": 0,
#           "off_heap": {
#             "total_size_bytes": 0,
#             "total_veb_size_bytes": 0,
#             "total_vec_size_bytes": 0,
#             "total_veq_size_bytes": 0,
#             "total_vex_size_bytes": 0
#           }
#         },
#         "sparse_vector": { "value_count": 0 }
#       }
#     }
#   }
# }
#
#
#
# ```

# %%
index_name_4 = "neurone_4"
settings = {
    "settings": {   
        "number_of_shards": 4,
        "number_of_replicas": 0,
        "analysis": {
              "analyzer": {
                "custom_fr_analyzer": {
                  "type": "custom",
                  "tokenizer": "standard",
                  "filter": [
                    "lowercase",
                    "asciifolding",
                    "french_stop",
                    "french_stemmer"
                  ]
                }
              },
              "filter": {
                "french_stop": {
                  "type": "stop",
                  "stopwords": "_french_"
                },
                "french_stemmer": {
                  "type": "stemmer",
                  "language": "french"
                    }
                }
          

        }
    },
    "mappings": {
        "properties": {
            "text": {"type": "text", "analyzer": "custom_fr_analyzer"}
        }
    }
}


es.indices.create(index=index_name_4, body=settings)
# Out:
# c:\Users\omar_\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'astrolastic.francecentral.cloudapp.azure.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'neurone_4'})

# %%
docs_4 = [{"_id": i, "_source":{"text": corpus[i]}, "_index":"neurone_4" } for i in range(len(corpus))]
helpers.bulk(es, docs_4)
# Out:
# c:\Users\omar_\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'astrolastic.francecentral.cloudapp.azure.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# (20, [])

# %%
stats_4 = es.indices.stats(index="neurone_4")
print(stats_4)
# Out:
# {'_shards': {'total': 4, 'successful': 4, 'failed': 0}, '_all': {'primaries': {'docs': {'count': 20, 'deleted': 0, 'total_size_in_bytes': 20877}, 'shard_stats': {'total_count': 4}, 'store': {'size_in_bytes': 21785, 'total_data_set_size_in_bytes': 21785, 'reserved_in_bytes': 0}, 'indexing': {'index_total': 20, 'index_time_in_millis': 9, 'index_current': 0, 'index_failed': 0, 'index_failed_due_to_version_conflict': 0, 'delete_total': 0, 'delete_time_in_millis': 0, 'delete_current': 0, 'noop_update_total': 0, 'is_throttled': False, 'throttle_time_in_millis': 0, 'write_load': 5.765490988872641e-05, 'recent_write_load': 5.5619042126844145e-05, 'peak_write_load': 5.5619042126844145e-05}, 'get': {'total': 0, 'time_in_millis': 0, 'exists_total': 0, 'exists_time_in_millis': 0, 'missing_total': 0, 'missing_time_in_millis': 0, 'current': 0}, 'search': {'open_contexts': 0, 'query_total': 0, 'query_time_in_millis': 0, 'query_current': 0, 'query_failure': 0, 'fetch_total': 0, 'fetch_time_in_millis
# ...

# %% [markdown]
# ```json
#
# {
#   "_shards": { "total": 4, "successful": 4, "failed": 0 },
#   "_all": {
#     "primaries": {
#       "docs": { "count": 20, "deleted": 0, "total_size_in_bytes": 20877 },
#       "shard_stats": { "total_count": 4 },
#       "store": {
#         "size_in_bytes": 21785,
#         "total_data_set_size_in_bytes": 21785,
#         "reserved_in_bytes": 0
#       },
#       "indexing": {
#         "index_total": 20,
#         "index_time_in_millis": 9,
#         "index_current": 0,
#         "index_failed": 0,
#         "index_failed_due_to_version_conflict": 0,
#         "delete_total": 0,
#         "delete_time_in_millis": 0,
#         "delete_current": 0,
#         "noop_update_total": 0,
#         "is_throttled": false,
#         "throttle_time_in_millis": 0,
#         "write_load": 5.765490988872641e-5,
#         "recent_write_load": 5.5619042126844145e-5,
#         "peak_write_load": 5.5619042126844145e-5
#       },
#       "get": {
#         "total": 0,
#         "time_in_millis": 0,
#         "exists_total": 0,
#         "exists_time_in_millis": 0,
#         "missing_total": 0,
#         "missing_time_in_millis": 0,
#         "current": 0
#       },
#       "search": {
#         "open_contexts": 0,
#         "query_total": 0,
#         "query_time_in_millis": 0,
#         "query_current": 0,
#         "query_failure": 0,
#         "fetch_total": 0,
#         "fetch_time_in_millis": 0,
#         "fetch_current": 0,
#         "fetch_failure": 0,
#         "scroll_total": 0,
#         "scroll_time_in_millis": 0,
#         "scroll_current": 0,
#         "suggest_total": 0,
#         "suggest_time_in_millis": 0,
#         "suggest_current": 0,
#         "recent_search_load": 0.0
#       },
#       "merges": {
#         "current": 0,
#         "current_docs": 0,
#         "current_size_in_bytes": 0,
#         "total": 0,
#         "total_time_in_millis": 0,
#         "total_docs": 0,
#         "total_size_in_bytes": 0,
#         "total_stopped_time_in_millis": 0,
#         "total_throttled_time_in_millis": 0,
#         "total_auto_throttle_in_bytes": 83886080
#       },
#       "refresh": {
#         "total": 12,
#         "total_time_in_millis": 27,
#         "external_total": 12,
#         "external_total_time_in_millis": 27,
#         "listeners": 0
#       },
#       "flush": {
#         "total": 0,
#         "periodic": 0,
#         "total_time_in_millis": 0,
#         "total_time_excluding_waiting_on_lock_in_millis": 0
#       },
#       "warmer": { "current": 0, "total": 8, "total_time_in_millis": 0 },
#       "query_cache": {
#         "memory_size_in_bytes": 0,
#         "total_count": 0,
#         "hit_count": 0,
#         "miss_count": 0,
#         "cache_size": 0,
#         "cache_count": 0,
#         "evictions": 0
#       },
#       "fielddata": {
#         "memory_size_in_bytes": 0,
#         "evictions": 0,
#         "global_ordinals": { "build_time_in_millis": 0 }
#       },
#       "completion": { "size_in_bytes": 0 },
#       "segments": {
#         "count": 4,
#         "memory_in_bytes": 0,
#         "terms_memory_in_bytes": 0,
#         "stored_fields_memory_in_bytes": 0,
#         "term_vectors_memory_in_bytes": 0,
#         "norms_memory_in_bytes": 0,
#         "points_memory_in_bytes": 0,
#         "doc_values_memory_in_bytes": 0,
#         "index_writer_memory_in_bytes": 0,
#         "version_map_memory_in_bytes": 0,
#         "fixed_bit_set_memory_in_bytes": 0,
#         "max_unsafe_auto_id_timestamp": -1,
#         "file_sizes": {}
#       },
#       "translog": {
#         "operations": 20,
#         "size_in_bytes": 3308,
#         "uncommitted_operations": 20,
#         "uncommitted_size_in_bytes": 3308,
#         "earliest_last_modified_age": 38110
#       },
#       "request_cache": {
#         "memory_size_in_bytes": 0,
#         "evictions": 0,
#         "hit_count": 0,
#         "miss_count": 0
#       },
#       "recovery": {
#         "current_as_source": 0,
#         "current_as_target": 0,
#         "throttle_time_in_millis": 0
#       },
#       "bulk": {
#         "total_operations": 4,
#         "total_time_in_millis": 9,
#         "total_size_in_bytes": 2157,
#         "avg_time_in_millis": 0,
#         "avg_size_in_bytes": 53
#       },
#       "dense_vector": {
#         "value_count": 0,
#         "off_heap": {
#           "total_size_bytes": 0,
#           "total_veb_size_bytes": 0,
#           "total_vec_size_bytes": 0,
#           "total_veq_size_bytes": 0,
#           "total_vex_size_bytes": 0
#         }
#       },
#       "sparse_vector": { "value_count": 0 }
#     },
#     "total": {
#       "docs": { "count": 20, "deleted": 0, "total_size_in_bytes": 20877 },
#       "shard_stats": { "total_count": 4 },
#       "store": {
#         "size_in_bytes": 21785,
#         "total_data_set_size_in_bytes": 21785,
#         "reserved_in_bytes": 0
#       },
#       "indexing": {
#         "index_total": 20,
#         "index_time_in_millis": 9,
#         "index_current": 0,
#         "index_failed": 0,
#         "index_failed_due_to_version_conflict": 0,
#         "delete_total": 0,
#         "delete_time_in_millis": 0,
#         "delete_current": 0,
#         "noop_update_total": 0,
#         "is_throttled": false,
#         "throttle_time_in_millis": 0,
#         "write_load": 5.765490988872641e-5,
#         "recent_write_load": 5.5619042126844145e-5,
#         "peak_write_load": 5.5619042126844145e-5
#       },
#       "get": {
#         "total": 0,
#         "time_in_millis": 0,
#         "exists_total": 0,
#         "exists_time_in_millis": 0,
#         "missing_total": 0,
#         "missing_time_in_millis": 0,
#         "current": 0
#       },
#       "search": {
#         "open_contexts": 0,
#         "query_total": 0,
#         "query_time_in_millis": 0,
#         "query_current": 0,
#         "query_failure": 0,
#         "fetch_total": 0,
#         "fetch_time_in_millis": 0,
#         "fetch_current": 0,
#         "fetch_failure": 0,
#         "scroll_total": 0,
#         "scroll_time_in_millis": 0,
#         "scroll_current": 0,
#         "suggest_total": 0,
#         "suggest_time_in_millis": 0,
#         "suggest_current": 0,
#         "recent_search_load": 0.0
#       },
#       "merges": {
#         "current": 0,
#         "current_docs": 0,
#         "current_size_in_bytes": 0,
#         "total": 0,
#         "total_time_in_millis": 0,
#         "total_docs": 0,
#         "total_size_in_bytes": 0,
#         "total_stopped_time_in_millis": 0,
#         "total_throttled_time_in_millis": 0,
#         "total_auto_throttle_in_bytes": 83886080
#       },
#       "refresh": {
#         "total": 12,
#         "total_time_in_millis": 27,
#         "external_total": 12,
#         "external_total_time_in_millis": 27,
#         "listeners": 0
#       },
#       "flush": {
#         "total": 0,
#         "periodic": 0,
#         "total_time_in_millis": 0,
#         "total_time_excluding_waiting_on_lock_in_millis": 0
#       },
#       "warmer": { "current": 0, "total": 8, "total_time_in_millis": 0 },
#       "query_cache": {
#         "memory_size_in_bytes": 0,
#         "total_count": 0,
#         "hit_count": 0,
#         "miss_count": 0,
#         "cache_size": 0,
#         "cache_count": 0,
#         "evictions": 0
#       },
#       "fielddata": {
#         "memory_size_in_bytes": 0,
#         "evictions": 0,
#         "global_ordinals": { "build_time_in_millis": 0 }
#       },
#       "completion": { "size_in_bytes": 0 },
#       "segments": {
#         "count": 4,
#         "memory_in_bytes": 0,
#         "terms_memory_in_bytes": 0,
#         "stored_fields_memory_in_bytes": 0,
#         "term_vectors_memory_in_bytes": 0,
#         "norms_memory_in_bytes": 0,
#         "points_memory_in_bytes": 0,
#         "doc_values_memory_in_bytes": 0,
#         "index_writer_memory_in_bytes": 0,
#         "version_map_memory_in_bytes": 0,
#         "fixed_bit_set_memory_in_bytes": 0,
#         "max_unsafe_auto_id_timestamp": -1,
#         "file_sizes": {}
#       },
#       "translog": {
#         "operations": 20,
#         "size_in_bytes": 3308,
#         "uncommitted_operations": 20,
#         "uncommitted_size_in_bytes": 3308,
#         "earliest_last_modified_age": 38110
#       },
#       "request_cache": {
#         "memory_size_in_bytes": 0,
#         "evictions": 0,
#         "hit_count": 0,
#         "miss_count": 0
#       },
#       "recovery": {
#         "current_as_source": 0,
#         "current_as_target": 0,
#         "throttle_time_in_millis": 0
#       },
#       "bulk": {
#         "total_operations": 4,
#         "total_time_in_millis": 9,
#         "total_size_in_bytes": 2157,
#         "avg_time_in_millis": 0,
#         "avg_size_in_bytes": 53
#       },
#       "dense_vector": {
#         "value_count": 0,
#         "off_heap": {
#           "total_size_bytes": 0,
#           "total_veb_size_bytes": 0,
#           "total_vec_size_bytes": 0,
#           "total_veq_size_bytes": 0,
#           "total_vex_size_bytes": 0
#         }
#       },
#       "sparse_vector": { "value_count": 0 }
#     }
#   },
#   "indices": {
#     "neurone_4": {
#       "uuid": "txNMiYj0TfyhJkhd3AqNdw",
#       "health": "green",
#       "status": "open",
#       "primaries": {
#         "docs": { "count": 20, "deleted": 0, "total_size_in_bytes": 20877 },
#         "shard_stats": { "total_count": 4 },
#         "store": {
#           "size_in_bytes": 21785,
#           "total_data_set_size_in_bytes": 21785,
#           "reserved_in_bytes": 0
#         },
#         "indexing": {
#           "index_total": 20,
#           "index_time_in_millis": 9,
#           "index_current": 0,
#           "index_failed": 0,
#           "index_failed_due_to_version_conflict": 0,
#           "delete_total": 0,
#           "delete_time_in_millis": 0,
#           "delete_current": 0,
#           "noop_update_total": 0,
#           "is_throttled": false,
#           "throttle_time_in_millis": 0,
#           "write_load": 5.765490988872641e-5,
#           "recent_write_load": 5.5619042126844145e-5,
#           "peak_write_load": 5.5619042126844145e-5
#         },
#         "get": {
#           "total": 0,
#           "time_in_millis": 0,
#           "exists_total": 0,
#           "exists_time_in_millis": 0,
#           "missing_total": 0,
#           "missing_time_in_millis": 0,
#           "current": 0
#         },
#         "search": {
#           "open_contexts": 0,
#           "query_total": 0,
#           "query_time_in_millis": 0,
#           "query_current": 0,
#           "query_failure": 0,
#           "fetch_total": 0,
#           "fetch_time_in_millis": 0,
#           "fetch_current": 0,
#           "fetch_failure": 0,
#           "scroll_total": 0,
#           "scroll_time_in_millis": 0,
#           "scroll_current": 0,
#           "suggest_total": 0,
#           "suggest_time_in_millis": 0,
#           "suggest_current": 0,
#           "recent_search_load": 0.0
#         },
#         "merges": {
#           "current": 0,
#           "current_docs": 0,
#           "current_size_in_bytes": 0,
#           "total": 0,
#           "total_time_in_millis": 0,
#           "total_docs": 0,
#           "total_size_in_bytes": 0,
#           "total_stopped_time_in_millis": 0,
#           "total_throttled_time_in_millis": 0,
#           "total_auto_throttle_in_bytes": 83886080
#         },
#         "refresh": {
#           "total": 12,
#           "total_time_in_millis": 27,
#           "external_total": 12,
#           "external_total_time_in_millis": 27,
#           "listeners": 0
#         },
#         "flush": {
#           "total": 0,
#           "periodic": 0,
#           "total_time_in_millis": 0,
#           "total_time_excluding_waiting_on_lock_in_millis": 0
#         },
#         "warmer": { "current": 0, "total": 8, "total_time_in_millis": 0 },
#         "query_cache": {
#           "memory_size_in_bytes": 0,
#           "total_count": 0,
#           "hit_count": 0,
#           "miss_count": 0,
#           "cache_size": 0,
#           "cache_count": 0,
#           "evictions": 0
#         },
#         "fielddata": {
#           "memory_size_in_bytes": 0,
#           "evictions": 0,
#           "global_ordinals": { "build_time_in_millis": 0 }
#         },
#         "completion": { "size_in_bytes": 0 },
#         "segments": {
#           "count": 4,
#           "memory_in_bytes": 0,
#           "terms_memory_in_bytes": 0,
#           "stored_fields_memory_in_bytes": 0,
#           "term_vectors_memory_in_bytes": 0,
#           "norms_memory_in_bytes": 0,
#           "points_memory_in_bytes": 0,
#           "doc_values_memory_in_bytes": 0,
#           "index_writer_memory_in_bytes": 0,
#           "version_map_memory_in_bytes": 0,
#           "fixed_bit_set_memory_in_bytes": 0,
#           "max_unsafe_auto_id_timestamp": -1,
#           "file_sizes": {}
#         },
#         "translog": {
#           "operations": 20,
#           "size_in_bytes": 3308,
#           "uncommitted_operations": 20,
#           "uncommitted_size_in_bytes": 3308,
#           "earliest_last_modified_age": 38110
#         },
#         "request_cache": {
#           "memory_size_in_bytes": 0,
#           "evictions": 0,
#           "hit_count": 0,
#           "miss_count": 0
#         },
#         "recovery": {
#           "current_as_source": 0,
#           "current_as_target": 0,
#           "throttle_time_in_millis": 0
#         },
#         "bulk": {
#           "total_operations": 4,
#           "total_time_in_millis": 9,
#           "total_size_in_bytes": 2157,
#           "avg_time_in_millis": 0,
#           "avg_size_in_bytes": 53
#         },
#         "dense_vector": {
#           "value_count": 0,
#           "off_heap": {
#             "total_size_bytes": 0,
#             "total_veb_size_bytes": 0,
#             "total_vec_size_bytes": 0,
#             "total_veq_size_bytes": 0,
#             "total_vex_size_bytes": 0
#           }
#         },
#         "sparse_vector": { "value_count": 0 }
#       },
#       "total": {
#         "docs": { "count": 20, "deleted": 0, "total_size_in_bytes": 20877 },
#         "shard_stats": { "total_count": 4 },
#         "store": {
#           "size_in_bytes": 21785,
#           "total_data_set_size_in_bytes": 21785,
#           "reserved_in_bytes": 0
#         },
#         "indexing": {
#           "index_total": 20,
#           "index_time_in_millis": 9,
#           "index_current": 0,
#           "index_failed": 0,
#           "index_failed_due_to_version_conflict": 0,
#           "delete_total": 0,
#           "delete_time_in_millis": 0,
#           "delete_current": 0,
#           "noop_update_total": 0,
#           "is_throttled": false,
#           "throttle_time_in_millis": 0,
#           "write_load": 5.765490988872641e-5,
#           "recent_write_load": 5.5619042126844145e-5,
#           "peak_write_load": 5.5619042126844145e-5
#         },
#         "get": {
#           "total": 0,
#           "time_in_millis": 0,
#           "exists_total": 0,
#           "exists_time_in_millis": 0,
#           "missing_total": 0,
#           "missing_time_in_millis": 0,
#           "current": 0
#         },
#         "search": {
#           "open_contexts": 0,
#           "query_total": 0,
#           "query_time_in_millis": 0,
#           "query_current": 0,
#           "query_failure": 0,
#           "fetch_total": 0,
#           "fetch_time_in_millis": 0,
#           "fetch_current": 0,
#           "fetch_failure": 0,
#           "scroll_total": 0,
#           "scroll_time_in_millis": 0,
#           "scroll_current": 0,
#           "suggest_total": 0,
#           "suggest_time_in_millis": 0,
#           "suggest_current": 0,
#           "recent_search_load": 0.0
#         },
#         "merges": {
#           "current": 0,
#           "current_docs": 0,
#           "current_size_in_bytes": 0,
#           "total": 0,
#           "total_time_in_millis": 0,
#           "total_docs": 0,
#           "total_size_in_bytes": 0,
#           "total_stopped_time_in_millis": 0,
#           "total_throttled_time_in_millis": 0,
#           "total_auto_throttle_in_bytes": 83886080
#         },
#         "refresh": {
#           "total": 12,
#           "total_time_in_millis": 27,
#           "external_total": 12,
#           "external_total_time_in_millis": 27,
#           "listeners": 0
#         },
#         "flush": {
#           "total": 0,
#           "periodic": 0,
#           "total_time_in_millis": 0,
#           "total_time_excluding_waiting_on_lock_in_millis": 0
#         },
#         "warmer": { "current": 0, "total": 8, "total_time_in_millis": 0 },
#         "query_cache": {
#           "memory_size_in_bytes": 0,
#           "total_count": 0,
#           "hit_count": 0,
#           "miss_count": 0,
#           "cache_size": 0,
#           "cache_count": 0,
#           "evictions": 0
#         },
#         "fielddata": {
#           "memory_size_in_bytes": 0,
#           "evictions": 0,
#           "global_ordinals": { "build_time_in_millis": 0 }
#         },
#         "completion": { "size_in_bytes": 0 },
#         "segments": {
#           "count": 4,
#           "memory_in_bytes": 0,
#           "terms_memory_in_bytes": 0,
#           "stored_fields_memory_in_bytes": 0,
#           "term_vectors_memory_in_bytes": 0,
#           "norms_memory_in_bytes": 0,
#           "points_memory_in_bytes": 0,
#           "doc_values_memory_in_bytes": 0,
#           "index_writer_memory_in_bytes": 0,
#           "version_map_memory_in_bytes": 0,
#           "fixed_bit_set_memory_in_bytes": 0,
#           "max_unsafe_auto_id_timestamp": -1,
#           "file_sizes": {}
#         },
#         "translog": {
#           "operations": 20,
#           "size_in_bytes": 3308,
#           "uncommitted_operations": 20,
#           "uncommitted_size_in_bytes": 3308,
#           "earliest_last_modified_age": 38110
#         },
#         "request_cache": {
#           "memory_size_in_bytes": 0,
#           "evictions": 0,
#           "hit_count": 0,
#           "miss_count": 0
#         },
#         "recovery": {
#           "current_as_source": 0,
#           "current_as_target": 0,
#           "throttle_time_in_millis": 0
#         },
#         "bulk": {
#           "total_operations": 4,
#           "total_time_in_millis": 9,
#           "total_size_in_bytes": 2157,
#           "avg_time_in_millis": 0,
#           "avg_size_in_bytes": 53
#         },
#         "dense_vector": {
#           "value_count": 0,
#           "off_heap": {
#             "total_size_bytes": 0,
#             "total_veb_size_bytes": 0,
#             "total_vec_size_bytes": 0,
#             "total_veq_size_bytes": 0,
#             "total_vex_size_bytes": 0
#           }
#         },
#         "sparse_vector": { "value_count": 0 }
#       }
#     }
#   }
# }
#
#
# ```

# %%
es.indices.forcemerge(index=index_name_4, max_num_segments=1)
# Out:
# c:\Users\omar_\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'astrolastic.francecentral.cloudapp.azure.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ObjectApiResponse({'_shards': {'total': 4, 'successful': 4, 'failed': 0}})

# %%
stats_4 = es.indices.stats(index="neurone_4")
print(stats_4)
# Out:
# {'_shards': {'total': 4, 'successful': 4, 'failed': 0}, '_all': {'primaries': {'docs': {'count': 20, 'deleted': 0, 'total_size_in_bytes': 20877}, 'shard_stats': {'total_count': 4}, 'store': {'size_in_bytes': 22369, 'total_data_set_size_in_bytes': 22369, 'reserved_in_bytes': 0}, 'indexing': {'index_total': 20, 'index_time_in_millis': 9, 'index_current': 0, 'index_failed': 0, 'index_failed_due_to_version_conflict': 0, 'delete_total': 0, 'delete_time_in_millis': 0, 'delete_current': 0, 'noop_update_total': 0, 'is_throttled': False, 'throttle_time_in_millis': 0, 'write_load': 5.0034886522939776e-06, 'recent_write_load': 2.613964678078151e-06, 'peak_write_load': 5.5614151285853616e-05}, 'get': {'total': 0, 'time_in_millis': 0, 'exists_total': 0, 'exists_time_in_millis': 0, 'missing_total': 0, 'missing_time_in_millis': 0, 'current': 0}, 'search': {'open_contexts': 0, 'query_total': 0, 'query_time_in_millis': 0, 'query_current': 0, 'query_failure': 0, 'fetch_total': 0, 'fetch_time_in_millis
# ...

# %% [markdown]
# ```json
#
#
# {
#   "_shards": { "total": 4, "successful": 4, "failed": 0 },
#   "_all": {
#     "primaries": {
#       "docs": { "count": 20, "deleted": 0, "total_size_in_bytes": 20877 },
#       "shard_stats": { "total_count": 4 },
#       "store": {
#         "size_in_bytes": 22369,
#         "total_data_set_size_in_bytes": 22369,
#         "reserved_in_bytes": 0
#       },
#       "indexing": {
#         "index_total": 20,
#         "index_time_in_millis": 9,
#         "index_current": 0,
#         "index_failed": 0,
#         "index_failed_due_to_version_conflict": 0,
#         "delete_total": 0,
#         "delete_time_in_millis": 0,
#         "delete_current": 0,
#         "noop_update_total": 0,
#         "is_throttled": false,
#         "throttle_time_in_millis": 0,
#         "write_load": 5.0034886522939776e-6,
#         "recent_write_load": 2.613964678078151e-6,
#         "peak_write_load": 5.5614151285853616e-5
#       },
#       "get": {
#         "total": 0,
#         "time_in_millis": 0,
#         "exists_total": 0,
#         "exists_time_in_millis": 0,
#         "missing_total": 0,
#         "missing_time_in_millis": 0,
#         "current": 0
#       },
#       "search": {
#         "open_contexts": 0,
#         "query_total": 0,
#         "query_time_in_millis": 0,
#         "query_current": 0,
#         "query_failure": 0,
#         "fetch_total": 0,
#         "fetch_time_in_millis": 0,
#         "fetch_current": 0,
#         "fetch_failure": 0,
#         "scroll_total": 0,
#         "scroll_time_in_millis": 0,
#         "scroll_current": 0,
#         "suggest_total": 0,
#         "suggest_time_in_millis": 0,
#         "suggest_current": 0,
#         "recent_search_load": 0.0
#       },
#       "merges": {
#         "current": 0,
#         "current_docs": 0,
#         "current_size_in_bytes": 0,
#         "total": 0,
#         "total_time_in_millis": 0,
#         "total_docs": 0,
#         "total_size_in_bytes": 0,
#         "total_stopped_time_in_millis": 0,
#         "total_throttled_time_in_millis": 0,
#         "total_auto_throttle_in_bytes": 83886080
#       },
#       "refresh": {
#         "total": 28,
#         "total_time_in_millis": 27,
#         "external_total": 20,
#         "external_total_time_in_millis": 27,
#         "listeners": 0
#       },
#       "flush": {
#         "total": 4,
#         "periodic": 4,
#         "total_time_in_millis": 126,
#         "total_time_excluding_waiting_on_lock_in_millis": 188
#       },
#       "warmer": { "current": 0, "total": 16, "total_time_in_millis": 0 },
#       "query_cache": {
#         "memory_size_in_bytes": 0,
#         "total_count": 0,
#         "hit_count": 0,
#         "miss_count": 0,
#         "cache_size": 0,
#         "cache_count": 0,
#         "evictions": 0
#       },
#       "fielddata": {
#         "memory_size_in_bytes": 0,
#         "evictions": 0,
#         "global_ordinals": { "build_time_in_millis": 0 }
#       },
#       "completion": { "size_in_bytes": 0 },
#       "segments": {
#         "count": 4,
#         "memory_in_bytes": 0,
#         "terms_memory_in_bytes": 0,
#         "stored_fields_memory_in_bytes": 0,
#         "term_vectors_memory_in_bytes": 0,
#         "norms_memory_in_bytes": 0,
#         "points_memory_in_bytes": 0,
#         "doc_values_memory_in_bytes": 0,
#         "index_writer_memory_in_bytes": 0,
#         "version_map_memory_in_bytes": 0,
#         "fixed_bit_set_memory_in_bytes": 0,
#         "max_unsafe_auto_id_timestamp": -1,
#         "file_sizes": {}
#       },
#       "translog": {
#         "operations": 0,
#         "size_in_bytes": 220,
#         "uncommitted_operations": 0,
#         "uncommitted_size_in_bytes": 220,
#         "earliest_last_modified_age": 213211
#       },
#       "request_cache": {
#         "memory_size_in_bytes": 0,
#         "evictions": 0,
#         "hit_count": 0,
#         "miss_count": 0
#       },
#       "recovery": {
#         "current_as_source": 0,
#         "current_as_target": 0,
#         "throttle_time_in_millis": 0
#       },
#       "bulk": {
#         "total_operations": 4,
#         "total_time_in_millis": 9,
#         "total_size_in_bytes": 2157,
#         "avg_time_in_millis": 0,
#         "avg_size_in_bytes": 53
#       },
#       "dense_vector": {
#         "value_count": 0,
#         "off_heap": {
#           "total_size_bytes": 0,
#           "total_veb_size_bytes": 0,
#           "total_vec_size_bytes": 0,
#           "total_veq_size_bytes": 0,
#           "total_vex_size_bytes": 0
#         }
#       },
#       "sparse_vector": { "value_count": 0 }
#     },
#     "total": {
#       "docs": { "count": 20, "deleted": 0, "total_size_in_bytes": 20877 },
#       "shard_stats": { "total_count": 4 },
#       "store": {
#         "size_in_bytes": 22369,
#         "total_data_set_size_in_bytes": 22369,
#         "reserved_in_bytes": 0
#       },
#       "indexing": {
#         "index_total": 20,
#         "index_time_in_millis": 9,
#         "index_current": 0,
#         "index_failed": 0,
#         "index_failed_due_to_version_conflict": 0,
#         "delete_total": 0,
#         "delete_time_in_millis": 0,
#         "delete_current": 0,
#         "noop_update_total": 0,
#         "is_throttled": false,
#         "throttle_time_in_millis": 0,
#         "write_load": 5.0034886522939776e-6,
#         "recent_write_load": 2.613964678078151e-6,
#         "peak_write_load": 5.5614151285853616e-5
#       },
#       "get": {
#         "total": 0,
#         "time_in_millis": 0,
#         "exists_total": 0,
#         "exists_time_in_millis": 0,
#         "missing_total": 0,
#         "missing_time_in_millis": 0,
#         "current": 0
#       },
#       "search": {
#         "open_contexts": 0,
#         "query_total": 0,
#         "query_time_in_millis": 0,
#         "query_current": 0,
#         "query_failure": 0,
#         "fetch_total": 0,
#         "fetch_time_in_millis": 0,
#         "fetch_current": 0,
#         "fetch_failure": 0,
#         "scroll_total": 0,
#         "scroll_time_in_millis": 0,
#         "scroll_current": 0,
#         "suggest_total": 0,
#         "suggest_time_in_millis": 0,
#         "suggest_current": 0,
#         "recent_search_load": 0.0
#       },
#       "merges": {
#         "current": 0,
#         "current_docs": 0,
#         "current_size_in_bytes": 0,
#         "total": 0,
#         "total_time_in_millis": 0,
#         "total_docs": 0,
#         "total_size_in_bytes": 0,
#         "total_stopped_time_in_millis": 0,
#         "total_throttled_time_in_millis": 0,
#         "total_auto_throttle_in_bytes": 83886080
#       },
#       "refresh": {
#         "total": 28,
#         "total_time_in_millis": 27,
#         "external_total": 20,
#         "external_total_time_in_millis": 27,
#         "listeners": 0
#       },
#       "flush": {
#         "total": 4,
#         "periodic": 4,
#         "total_time_in_millis": 126,
#         "total_time_excluding_waiting_on_lock_in_millis": 188
#       },
#       "warmer": { "current": 0, "total": 16, "total_time_in_millis": 0 },
#       "query_cache": {
#         "memory_size_in_bytes": 0,
#         "total_count": 0,
#         "hit_count": 0,
#         "miss_count": 0,
#         "cache_size": 0,
#         "cache_count": 0,
#         "evictions": 0
#       },
#       "fielddata": {
#         "memory_size_in_bytes": 0,
#         "evictions": 0,
#         "global_ordinals": { "build_time_in_millis": 0 }
#       },
#       "completion": { "size_in_bytes": 0 },
#       "segments": {
#         "count": 4,
#         "memory_in_bytes": 0,
#         "terms_memory_in_bytes": 0,
#         "stored_fields_memory_in_bytes": 0,
#         "term_vectors_memory_in_bytes": 0,
#         "norms_memory_in_bytes": 0,
#         "points_memory_in_bytes": 0,
#         "doc_values_memory_in_bytes": 0,
#         "index_writer_memory_in_bytes": 0,
#         "version_map_memory_in_bytes": 0,
#         "fixed_bit_set_memory_in_bytes": 0,
#         "max_unsafe_auto_id_timestamp": -1,
#         "file_sizes": {}
#       },
#       "translog": {
#         "operations": 0,
#         "size_in_bytes": 220,
#         "uncommitted_operations": 0,
#         "uncommitted_size_in_bytes": 220,
#         "earliest_last_modified_age": 213211
#       },
#       "request_cache": {
#         "memory_size_in_bytes": 0,
#         "evictions": 0,
#         "hit_count": 0,
#         "miss_count": 0
#       },
#       "recovery": {
#         "current_as_source": 0,
#         "current_as_target": 0,
#         "throttle_time_in_millis": 0
#       },
#       "bulk": {
#         "total_operations": 4,
#         "total_time_in_millis": 9,
#         "total_size_in_bytes": 2157,
#         "avg_time_in_millis": 0,
#         "avg_size_in_bytes": 53
#       },
#       "dense_vector": {
#         "value_count": 0,
#         "off_heap": {
#           "total_size_bytes": 0,
#           "total_veb_size_bytes": 0,
#           "total_vec_size_bytes": 0,
#           "total_veq_size_bytes": 0,
#           "total_vex_size_bytes": 0
#         }
#       },
#       "sparse_vector": { "value_count": 0 }
#     }
#   },
#   "indices": {
#     "neurone_4": {
#       "uuid": "txNMiYj0TfyhJkhd3AqNdw",
#       "health": "green",
#       "status": "open",
#       "primaries": {
#         "docs": { "count": 20, "deleted": 0, "total_size_in_bytes": 20877 },
#         "shard_stats": { "total_count": 4 },
#         "store": {
#           "size_in_bytes": 22369,
#           "total_data_set_size_in_bytes": 22369,
#           "reserved_in_bytes": 0
#         },
#         "indexing": {
#           "index_total": 20,
#           "index_time_in_millis": 9,
#           "index_current": 0,
#           "index_failed": 0,
#           "index_failed_due_to_version_conflict": 0,
#           "delete_total": 0,
#           "delete_time_in_millis": 0,
#           "delete_current": 0,
#           "noop_update_total": 0,
#           "is_throttled": false,
#           "throttle_time_in_millis": 0,
#           "write_load": 5.0034886522939776e-6,
#           "recent_write_load": 2.613964678078151e-6,
#           "peak_write_load": 5.5614151285853616e-5
#         },
#         "get": {
#           "total": 0,
#           "time_in_millis": 0,
#           "exists_total": 0,
#           "exists_time_in_millis": 0,
#           "missing_total": 0,
#           "missing_time_in_millis": 0,
#           "current": 0
#         },
#         "search": {
#           "open_contexts": 0,
#           "query_total": 0,
#           "query_time_in_millis": 0,
#           "query_current": 0,
#           "query_failure": 0,
#           "fetch_total": 0,
#           "fetch_time_in_millis": 0,
#           "fetch_current": 0,
#           "fetch_failure": 0,
#           "scroll_total": 0,
#           "scroll_time_in_millis": 0,
#           "scroll_current": 0,
#           "suggest_total": 0,
#           "suggest_time_in_millis": 0,
#           "suggest_current": 0,
#           "recent_search_load": 0.0
#         },
#         "merges": {
#           "current": 0,
#           "current_docs": 0,
#           "current_size_in_bytes": 0,
#           "total": 0,
#           "total_time_in_millis": 0,
#           "total_docs": 0,
#           "total_size_in_bytes": 0,
#           "total_stopped_time_in_millis": 0,
#           "total_throttled_time_in_millis": 0,
#           "total_auto_throttle_in_bytes": 83886080
#         },
#         "refresh": {
#           "total": 28,
#           "total_time_in_millis": 27,
#           "external_total": 20,
#           "external_total_time_in_millis": 27,
#           "listeners": 0
#         },
#         "flush": {
#           "total": 4,
#           "periodic": 4,
#           "total_time_in_millis": 126,
#           "total_time_excluding_waiting_on_lock_in_millis": 188
#         },
#         "warmer": { "current": 0, "total": 16, "total_time_in_millis": 0 },
#         "query_cache": {
#           "memory_size_in_bytes": 0,
#           "total_count": 0,
#           "hit_count": 0,
#           "miss_count": 0,
#           "cache_size": 0,
#           "cache_count": 0,
#           "evictions": 0
#         },
#         "fielddata": {
#           "memory_size_in_bytes": 0,
#           "evictions": 0,
#           "global_ordinals": { "build_time_in_millis": 0 }
#         },
#         "completion": { "size_in_bytes": 0 },
#         "segments": {
#           "count": 4,
#           "memory_in_bytes": 0,
#           "terms_memory_in_bytes": 0,
#           "stored_fields_memory_in_bytes": 0,
#           "term_vectors_memory_in_bytes": 0,
#           "norms_memory_in_bytes": 0,
#           "points_memory_in_bytes": 0,
#           "doc_values_memory_in_bytes": 0,
#           "index_writer_memory_in_bytes": 0,
#           "version_map_memory_in_bytes": 0,
#           "fixed_bit_set_memory_in_bytes": 0,
#           "max_unsafe_auto_id_timestamp": -1,
#           "file_sizes": {}
#         },
#         "translog": {
#           "operations": 0,
#           "size_in_bytes": 220,
#           "uncommitted_operations": 0,
#           "uncommitted_size_in_bytes": 220,
#           "earliest_last_modified_age": 213211
#         },
#         "request_cache": {
#           "memory_size_in_bytes": 0,
#           "evictions": 0,
#           "hit_count": 0,
#           "miss_count": 0
#         },
#         "recovery": {
#           "current_as_source": 0,
#           "current_as_target": 0,
#           "throttle_time_in_millis": 0
#         },
#         "bulk": {
#           "total_operations": 4,
#           "total_time_in_millis": 9,
#           "total_size_in_bytes": 2157,
#           "avg_time_in_millis": 0,
#           "avg_size_in_bytes": 53
#         },
#         "dense_vector": {
#           "value_count": 0,
#           "off_heap": {
#             "total_size_bytes": 0,
#             "total_veb_size_bytes": 0,
#             "total_vec_size_bytes": 0,
#             "total_veq_size_bytes": 0,
#             "total_vex_size_bytes": 0
#           }
#         },
#         "sparse_vector": { "value_count": 0 }
#       },
#       "total": {
#         "docs": { "count": 20, "deleted": 0, "total_size_in_bytes": 20877 },
#         "shard_stats": { "total_count": 4 },
#         "store": {
#           "size_in_bytes": 22369,
#           "total_data_set_size_in_bytes": 22369,
#           "reserved_in_bytes": 0
#         },
#         "indexing": {
#           "index_total": 20,
#           "index_time_in_millis": 9,
#           "index_current": 0,
#           "index_failed": 0,
#           "index_failed_due_to_version_conflict": 0,
#           "delete_total": 0,
#           "delete_time_in_millis": 0,
#           "delete_current": 0,
#           "noop_update_total": 0,
#           "is_throttled": false,
#           "throttle_time_in_millis": 0,
#           "write_load": 5.0034886522939776e-6,
#           "recent_write_load": 2.613964678078151e-6,
#           "peak_write_load": 5.5614151285853616e-5
#         },
#         "get": {
#           "total": 0,
#           "time_in_millis": 0,
#           "exists_total": 0,
#           "exists_time_in_millis": 0,
#           "missing_total": 0,
#           "missing_time_in_millis": 0,
#           "current": 0
#         },
#         "search": {
#           "open_contexts": 0,
#           "query_total": 0,
#           "query_time_in_millis": 0,
#           "query_current": 0,
#           "query_failure": 0,
#           "fetch_total": 0,
#           "fetch_time_in_millis": 0,
#           "fetch_current": 0,
#           "fetch_failure": 0,
#           "scroll_total": 0,
#           "scroll_time_in_millis": 0,
#           "scroll_current": 0,
#           "suggest_total": 0,
#           "suggest_time_in_millis": 0,
#           "suggest_current": 0,
#           "recent_search_load": 0.0
#         },
#         "merges": {
#           "current": 0,
#           "current_docs": 0,
#           "current_size_in_bytes": 0,
#           "total": 0,
#           "total_time_in_millis": 0,
#           "total_docs": 0,
#           "total_size_in_bytes": 0,
#           "total_stopped_time_in_millis": 0,
#           "total_throttled_time_in_millis": 0,
#           "total_auto_throttle_in_bytes": 83886080
#         },
#         "refresh": {
#           "total": 28,
#           "total_time_in_millis": 27,
#           "external_total": 20,
#           "external_total_time_in_millis": 27,
#           "listeners": 0
#         },
#         "flush": {
#           "total": 4,
#           "periodic": 4,
#           "total_time_in_millis": 126,
#           "total_time_excluding_waiting_on_lock_in_millis": 188
#         },
#         "warmer": { "current": 0, "total": 16, "total_time_in_millis": 0 },
#         "query_cache": {
#           "memory_size_in_bytes": 0,
#           "total_count": 0,
#           "hit_count": 0,
#           "miss_count": 0,
#           "cache_size": 0,
#           "cache_count": 0,
#           "evictions": 0
#         },
#         "fielddata": {
#           "memory_size_in_bytes": 0,
#           "evictions": 0,
#           "global_ordinals": { "build_time_in_millis": 0 }
#         },
#         "completion": { "size_in_bytes": 0 },
#         "segments": {
#           "count": 4,
#           "memory_in_bytes": 0,
#           "terms_memory_in_bytes": 0,
#           "stored_fields_memory_in_bytes": 0,
#           "term_vectors_memory_in_bytes": 0,
#           "norms_memory_in_bytes": 0,
#           "points_memory_in_bytes": 0,
#           "doc_values_memory_in_bytes": 0,
#           "index_writer_memory_in_bytes": 0,
#           "version_map_memory_in_bytes": 0,
#           "fixed_bit_set_memory_in_bytes": 0,
#           "max_unsafe_auto_id_timestamp": -1,
#           "file_sizes": {}
#         },
#         "translog": {
#           "operations": 0,
#           "size_in_bytes": 220,
#           "uncommitted_operations": 0,
#           "uncommitted_size_in_bytes": 220,
#           "earliest_last_modified_age": 213211
#         },
#         "request_cache": {
#           "memory_size_in_bytes": 0,
#           "evictions": 0,
#           "hit_count": 0,
#           "miss_count": 0
#         },
#         "recovery": {
#           "current_as_source": 0,
#           "current_as_target": 0,
#           "throttle_time_in_millis": 0
#         },
#         "bulk": {
#           "total_operations": 4,
#           "total_time_in_millis": 9,
#           "total_size_in_bytes": 2157,
#           "avg_time_in_millis": 0,
#           "avg_size_in_bytes": 53
#         },
#         "dense_vector": {
#           "value_count": 0,
#           "off_heap": {
#             "total_size_bytes": 0,
#             "total_veb_size_bytes": 0,
#             "total_vec_size_bytes": 0,
#             "total_veq_size_bytes": 0,
#             "total_vex_size_bytes": 0
#           }
#         },
#         "sparse_vector": { "value_count": 0 }
#       }
#     }
#   }
# }
#
# ```
